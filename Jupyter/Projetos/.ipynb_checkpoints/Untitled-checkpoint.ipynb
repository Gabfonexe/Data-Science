# %%
import yfinance
import pyperclip
import pyautogui
import time
import matplotlib.pyplot as plt

ticker = input("Digite o código da ação: ")
periodo = input("Digite o período desejado (ano:Y, mês: M, dia: D): ")
destinatario = input("Digite o destino de email que deseja enviar o relatório: ")
assunto_email = input("Digite o assunto do email: ")
dados = yfinance.Ticker(ticker)
tabela = dados.history(periodo)
fechamento = tabela.Close
grafico = fechamento.plot()
plt.savefig('Grafico.png')
maxima = fechamento.max()
minima = fechamento.min()
atual = fechamento[-1]


mensagem = f"""
Olá, segue abaixo os dados da ação {ticker} no período de {periodo} :
Valor mais Alto :  R$ {round(maxima, 2)}
Valor mais Baixo : R$ {round(minima,2 )}
Valor Atual :      R$ {round(atual, 2)}
Gráfico da análise:
"""

pyautogui.PAUSE = 2
pyautogui.hotkey("ctrl", "t")
pyperclip.copy('https://www.gmail.com/')
pyautogui.hotkey('ctrl', 'v')
pyautogui.press("enter")
pyautogui.click(x=76, y=190)
pyperclip.copy(destinatario)
time.sleep(1)
pyautogui.hotkey("ctrl", "v")
time.sleep(1)
pyautogui.press("enter")
pyautogui.press('tab')
pyperclip.copy(assunto_email)
pyautogui.hotkey("ctrl", "v")
pyautogui.press("enter")
pyautogui.press('tab')
pyperclip.copy(mensagem)
pyautogui.hotkey("ctrl", "v")
pyautogui.click(x=1433, y=1013)
pyperclip.copy(r"C:\Users\bielf\Jupyter\Projetos\Grafico")
pyautogui.hotkey("ctrl", "v")
pyautogui.press("enter")
pyautogui.click(x=1325, y=1011)


print("tudo certo! ")
# Out:
# C:\Users\bielf\AppData\Roaming\Python\Python311\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
# Digite o código da ação: NFLX
# Digite o período desejado (ano:Y, mês: M, dia: D): 1y
# Digite o destino de email que deseja enviar o relatório: tsoft244@gmail.com
# Digite o assunto do email: Relatório Ações
# C:\Users\bielf\AppData\Roaming\Python\Python311\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# C:\Users\bielf\AppData\Local\Temp\ipykernel_20552\2629896266.py:18: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   atual = fechamento[-1]
# tudo certo!

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 print(teste)
#
# NameError: name 'teste' is not defined

# %%
time.sleep(5)
pyautogui.position()
